# %%
def normal_function():
    print(1)
    print(2)
    print(3)

# %%
normal_function()
# Out:
# 1
# 2
# 3

# %%
def generator_function(): 
    yield 1
    yield 2 
    yield 3

# %%
gen = generator_function()

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 2

# %%
next(gen)
# Out:
# 3

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 next(gen)
#
# StopIteration:
