# %% [markdown]
# # EDA on Jobsearch API

# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


if __name__ == '__main__':
    query = 'lärare uppsala'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
# Out:
# Lärare i idrott och hälsa - Stavby skola, Uppsala kommun
# Lärare åk 5 - Liljeforsskolan, Uppsala kommun
# Lärare F-3 - Östra Stenhagenskolan, Uppsala kommun
# Timvikarie grundskola, Jensen education Aktiebolag
# Lärare i säkerhetstjänst, Försvarsmakten
# Yrkeslärare Byggnadsplåtslagare  Movant Uppsala, AcadeMedia Support AB
# Jobba som mellanstadielärare på Sveriges mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lågstadielärare på Sveriges mest personliga bemanningsföretag!, PersonalExpressen AB
#
# Number of hits = 8

# %%
example_search_return_number_of_hits(query)
# Out:
# Number of hits = 8

# %%
search_params = {'q': query, 'limit': 100}
json_response = _get_ads(search_params)
json_response
# Out:
# {'total': {'value': 8},
#  'positions': 10,
#  'query_time_in_millis': 2,
#  'result_time_in_millis': 16,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['lärare'],
#   'trait': [],
#   'location': ['uppsala'],
#   'skill_must': [],
#   'occupation_must': [],
#   'trait_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'trait_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '31477252',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31477252',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2120003005/logotyper/logo.png',
#    'headline': 'Lärare i idrott och hälsa - Stavby skola',
#    'application_deadline': '2026-09-28T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Välkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat. \r\n\r\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nVi kommer att begära utdrag ur belastningsregistret innan anställ
esättning enligt gällande löneavtal.</p><p>I din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.</p><p>En anställning hos Uppsala kommun kan komma att innebära en krigsplacering. \xa0</p>Löneform: Månadslön.\r\nAnställningsform: Tillsvidareanställning.\r\nVaraktighet: Tillsvidare, tillträde: Enligt öve ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120003005',
#     'name': 'Uppsala kommun',
#     'workplace': 'Uppsala kommun, Ledning Kommunal grundskola'},
#    'application_details': {'information': None,
#     'reference': 'UBN-2026-04530',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=bb7062b4-b34e-4e47-9e9d-202c3540288f&publishCode=PB&TK=d8c58a6b-4267-4bd4-800e-b9e856f6b0c6',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Lärare i grundskolan, årskurs 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'STADSHUSGATAN 2',
#     'postcode': '75321',
#     'city': 'Uppsala',
#     'coordinates': [17.6432127102467, 59.8594690046015]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'STADSHUSGATAN 2',
#      'postcode': '75321',
#      'city': 'Uppsala',
#      'coordinates': [17.6432127102467, 59.8594690046015]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Sandra   Grip Viklund',
#      'description': None,
#      'email': None,
#      'telephone': '+46187270110',
#      'contact_type': 'Rektor'}],
#    'publication_date': '2026-09-15T09:30:06',
#    'last_publication_date': '2026-09-28T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789457406768},
#   {'relevance': 1.0,
#    'id': '31473962',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31473962',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2120003005/logotyper/logo.png',
#    'headline': 'Lärare åk 5 - Liljeforsskolan',
#    'application_deadline': '2026-09-25T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Välkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat. \r\n\r\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nVi kommer att begära utdrag ur belastningsregistret innan anställning kan erbjudas för tjänster som enligt lag kräver det. Du kan läsa mer om vilka områden som berörs på polisens hemsida.\r\n\r\n1 plats(er). \r\n\r\n\nÄr du en skicklig lärare med ett starkt engagemang för samarbete, mångfald och inkludering? Trivs du i en verksamhet där nytänkande och lösningsfokus värdesätts? Då är Liljeforsskolan en arbetsplats där du kan utvecklas och göra skillnad.\nLiljeforsskolan är en F-5 skola som ligger i Gränbyområdet. På skolan går cirka 320 elever och där arbetar cirka 50 personal. Skolan ligger mitt i bostadsområdet, men är omgiven av vackra parker. Skolgården är stor och har gott om lekytor. Detta sammantaget inbjuder till kreativ och lärorik utevistelse!\nSkolan präglas av mångfald och flerspråkighet. Skolan har ett stort kompensatoriskt uppdrag och är en av Uppsalas skolor som är utvalda för särskilda stödinsatser. Detta betyder att skolan får olika bidrag som möjliggör en högre personalbemanning och mindre klasstorlekar än vad många andra skolor har.\nSkolan genomsyras av "Liljeforsandan" där trivseln är hög. Elevgruppen är studiemotiverad och både elever och personal är öppna och välkomnande. Personalen har ett stort engagemang och en hög kompetens, vilket möjliggör utveckling och ökad måluppfyllelse hos skolans alla elever.\nTjänsten är tidsbegränsad till och med 2027-06-11, med goda chanser till förlängning.\nBeskrivning av arbetsuppgifter\nSom lärare i denna tjänst undervisar du i ämnena engelska, matematik, NO och teknik alternativt engelska, matematik och SO. Du undervisar även i svenska. Meriterande är om du också har behörighet att undervisa i ämnet svenska som andraspråk.\nI denna tjänst kommer du att få möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, ditt kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument.\nVi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Ni samplanerar och sambedömer och tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.\nDu och dina kollegor delar på mentorsskapet, vilket innebär att du kommer att vara mentor för ett antal elever i årskursen.\nKvalifikationer\nVi söker dig som har svensk lärarlegitimation alternativt inväntar legitimation med behörighet att undervisa i svenska, engelska, matematik, NO och teknik alternativt svenska, engelska, matematik och SO i årskurs 4-6. För att lyckas i arbetet behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska.\nVi ser gärna att du är behörig att undervisa i svenska som andraspråk och erfarenhet av arbete i flerspråkig miljö. Har du erfarenhet av arbete med språkutvecklande arb
utifrån sina individuella förutsättningar.</p><p>Du och dina kollegor delar på mentorsskapet, vilket innebär att du kommer att vara mentor för ett antal elever i årskursen.</p><p><strong><em><strong>Kvalifikationer</strong></em></strong></p><p>Vi söker dig som har svensk lärarlegitimation alternativt inväntar legitimation med behörighet att undervisa i svenska, engelska, matematik, NO och teknik alternativt svenska, engelska, matematik och SO i årskurs 4-6. För att lyckas i arbetet behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska.</p><p>Vi ser gärna att du är behörig att undervisa i svenska som andraspråk och erfarenhet av arbete i flerspråkig miljö. Har du erfarenhet av arbete med språkutvecklande arbetssätt och it-kunskaper med inriktning mot pedagogiskt arbete ses det som meriterande.</p><p>Du har god pedagogisk insikt och anpassar undervisning och kommunikation utifrån elevers olika behov. Du är personligt mogen, flexibel och trygg i din yrkesroll samt har lätt att anpassa dig till förändrade förutsättningar. Du behåller lugn och fokus även i utmanande situationer och bidrar till en trygg lärmiljö.</p><p><strong><em><strong>Upplysningar</strong></em> ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120003005',
#     'name': 'Uppsala kommun',
#     'workplace': 'Uppsala kommun, Ledning Kommunal grundskola'},
#    'application_details': {'information': None,
#     'reference': 'UBN-2026-04524',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=1dd6ba75-2bb2-427d-a73d-c251ccf81336&publishCode=PB&TK=03de60d0-7899-442b-9196-c3c9a38ac5ca',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'Nzmh_iTb_z7h',
#     'label': 'Lärare i grundskolan, årskurs 4-6',
#     'legacy_ams_taxonomy_id': '7653'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'STADSHUSGATAN 2',
#     'postcode': '75321',
#     'city': 'Uppsala',
#     'coordinates': [17.6432127102467, 59.8594690046015]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'STADSHUSGATAN 2',
#      'postcode': '75321',
#      'city': 'Uppsala',
#      'coordinates': [17.6432127102467, 59.8594690046015]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Karin   Mann',
#      'description': None,
#      'email': None,
#      'telephone': '+46187270977',
#      'contact_type': 'Rektor'}],
#    'publication_date': '2026-09-14T13:45:05',
#    'last_publication_date': '2026-09-25T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789386305849},
#   {'relevance': 1.0,
#    'id': '31448784',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31448784',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2120003005/logotyper/logo.png',
#    'headline': 'Lärare F-3 - Östra Stenhagenskolan',
#    'application_deadline': '2026-09-20T23:59:59',
#    'number_of_vacancies': 2,
#    'description': {'text': 'Välkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat. \r\n\r\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nVi kommer att begära utdrag ur belastningsregistret innan anställning kan erbjudas för tjänster som enligt lag kräver det. Du kan läsa mer om vilka områden som berörs på polisens hemsida.\r\n\r\n2 plats(er). \r\n\r\n\nVill du göra skillnad för elever varje dag? Vi söker en engagerad lärare som tror på goda relationer, tydligt ledarskap och höga förväntningar. Hos oss arbetar lärare, elevhälsa och fritidspersonal nära tillsammans för att skapa en trygg och utvecklande skolmiljö där alla kan lyckas. Vi ser fram emot din ansökan!\nÖstra Stenhagenskolan är en kommunal F-6-skola där cirka 470 elever och 64 engagerade medarbetare tillsammans skapar en trygg, utvecklande och inspirerande lärmiljö. Skolan har tre paralleller i årskurs 1-6 och en flexibel organisation för eleverna i förskoleklass. För elever i förskoleklass till årskurs 3 finns fritidshemsverksamhet knuten till respektive årskurs. I våra lokaler finns även anpassad grundskola med egen ledning.\nPå Östra Stenhagenskolan präglas verksamheten av en stark tro på varje elevs möjligheter att lyckas. Vi arbetar utifrån ett helhetsperspektiv där lärande, trygghet och utveckling går hand i hand. Genom att skapa tillgängliga lärmiljöer och bygga goda relationer ger vi alla elever bästa möjliga förutsättningar att nå sina mål.\nHos oss arbetar pedagoger och elevhälsa nära tillsammans med elevens utveckling i centrum. Vi kombinerar tydliga kunskapsmål och höga förväntningar med ett starkt fokus på social utveckling och välmående. Vi är övertygade om att goda relationer, ett inkluderande förhållningssätt och en gemensam riktning leder till ökad måluppfyllelse för alla elever.\nSom medarbetare hos oss blir du en del av en professionell och utvecklingsinriktad organisation. Vi erbjuder en stimulerande arbetsmiljö där samarbete, engagemang och kollegialt lärande står i fokus. Här får du möjlighet att påverka, bidra till skolans fortsatta utveckling och växa i din yrkesroll. Tillsammans skapar vi en skola där både elever och medarbetare utvecklas, trivs och lyckas.\nBeskrivning av arbetsuppgifter\nSom lärare i denna tjänst undervisar du i årskurserna F-3. Du får möjligheten att göra skill
ssätt och en gemensam riktning leder till ökad måluppfyllelse för alla elever.</p><p>Som medarbetare hos oss blir du en del av en professionell och utvecklingsinriktad organisation. Vi erbjuder en stimulerande arbetsmiljö där samarbete, engagemang och kollegialt lärande står i fokus. Här får du möjlighet att påverka, bidra till skolans fortsatta utveckling och växa i din yrkesroll. Tillsammans skapar vi en skola där både elever och medarbetare utvecklas, trivs och lyckas.</p><p><strong><em><strong>Beskrivning av arbetsuppgifter</strong></em></strong></p><p>Som lärare i denna tjänst undervisar du i årskurserna F-3. Du får möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument.</p><p>Vi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.</p><p><strong><em><strong>Kvalifikationer</strong></em></strong></p><p>Vi söker dig som har svensk lärarlegitimation alternativt inväntar legitimation med behörighet att undervisa i årskurs F-3. För att lyckas i arbetet behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska.</p><p>Vi ser gärna att du har erfarenhet av arbete med språkutvecklande arbetssätt. Det är även meriterande om du har it-kunskaper med inriktning mot pedagogiskt arbete.</p><p>Du har pedagogisk insikt och en god förståelse för elevers olika sätt att lära och utvecklas. Du anpassar undervisning, bemötande och kommunikation utifrån elevernas behov och förutsättningar för att skapa goda förutsättningar för lärande. Du är initiativtagande och tar ansvar för att utveckla undervisningen, skapa engagemang i klassrumm ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120003005',
#     'name': 'Uppsala kommun',
#     'workplace': 'Uppsala kommun, Ledning Kommunal grundskola'},
#    'application_details': {'information': None,
#     'reference': 'UBN-2026-04340',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=258bdfba-b380-48be-9d2a-ed842a8c479e&publishCode=PB&TK=c0a7b682-a19a-42cb-8c95-337ea09b41a1',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'zGHj_2Jf_oKy',
#     'label': 'Lärare i grundskolan, årskurs 1-3',
#     'legacy_ams_taxonomy_id': '7652'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'STADSHUSGATAN 2',
#     'postcode': '75321',
#     'city': 'Uppsala',
#     'coordinates': [17.6432127102467, 59.8594690046015]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'STADSHUSGATAN 2',
#      'postcode': '75321',
#      'city': 'Uppsala',
#      'coordinates': [17.6432127102467, 59.8594690046015]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Kim   Milint',
#      'description': None,
#      'email': None,
#      'telephone': '+46187276492',
#      'contact_type': 'Rektor'}],
#    'publication_date': '2026-09-08T08:15:09',
#    'last_publication_date': '2026-09-20T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1788848109996},
#   {'relevance': 1.0,
#    'id': '31443216',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31443216',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5565327201/logotyper/logo.png',
#    'headline': 'Timvikarie grundskola',
#    'application_deadline': '2026-10-04T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Bli en nyckelperson i att forma framtidens studiekultur!\xa0JENSEN grundskola startade i Uppsala 2010 och är idag en omtyckt skola med nöjda elever och föräldrar. JENSEN grundskola Kåbo är en skola där eleverna kan gå från årskurs 4–9. I takt med att skolan växer söker vi nu en engagerad lärarvikarie som vill bli en del av vårt team.\nPå JENSEN går vi vår egen väg. Vi tror på disciplin, hälsa och att våga tänka stort. Som lärare hos oss blir du en del av ett sammansvetsat team med extremt högt engagemang – faktum är att över 90 % av våra medarbetare rekommenderar JENSEN som arbetsplats!\nVår höga nivå bekräftas gång på gång i Skolinspektionens granskningar. Vi kombinerar klassisk bildning med modern "träning för verkligheten" genom caseövningar och fokus på akademiskt skrivande. Vi tror på professionalism, en stark hälsoprofil och en tydlig dresscode som speglar våra ambitioner.\nArbetsuppgifter\n\xa0\nAtt arbeta som lärarvikarie innebär att stötta upp verksamheten när behov uppstår i verksamheten. Det handlar främst om korta uppdrag som kan passa bra för dig som studerar eller har annan sysselsättning, men det kan även öppnas möjligheter för längre anställningar för den som önskar.\n\xa0\nVi arbetar enligt ett pedagogiskt koncept som vi kallar Träning för verkligheten.\xa0Eftersom det är viktigt att även våra vikarier arbetar enligt vårt pedagogiska koncept går vi igenom detta vid ett eventuellt intervjutillfälle.\nKvalifikationer\n\xa0\nVi söker dig som har ett genuint intresse för att arbeta med barn och unga. Det är meriterande om du kan undervisa i flera ämnen. Du är pedagogisk i ditt förhållningssätt och känner dig trygg i rollen som en tydlig ledare. Vi ser gärna att du studerar på högskola eller universitet eller har en avslutad examen. Kanske är du l
ppnas möjligheter för längre anställningar för den som önskar.</p><p>\xa0</p><p>Vi arbetar enligt ett pedagogiskt koncept som vi kallar Träning för verkligheten.&nbsp;Eftersom det är viktigt att även våra vikarier arbetar enligt vårt pedagogiska koncept går vi igenom detta vid ett eventuellt intervjutillfälle.</p><p><strong>Kvalifikationer</strong></p><p>&nbsp;</p><p>Vi söker dig som har ett genuint intresse för att arbeta med barn och unga. Det är meriterande om du kan undervisa i flera ämnen. Du är pedagogisk i ditt förhållningssätt och känner dig trygg i rollen som en tydlig ledare. Vi ser gärna att du studerar på högskola eller universitet eller har en avslutad examen. Kanske är du lärarstudent och vill skaffa värdefull erfarenhet genom att arbeta som timvikarie?</p><p>\xa0</p><p>Som person är du ansvarstagande, initiativrik och kommunikativ. Du har lätt för att skapa goda relationer med både elever och kollegor och bidrar till en trygg och positiv lärmiljö. I rollen som vikarie arbetar du självständigt, samtidigt som du har ett nära samarbete och en löpande dialog med skolans lärare och övriga medarbetare.</p><p>För oss är det viktigt att du har möjlighet att rycka in med kort varsel och är flexibel när det gäller arbetstider.</p><p><strong>Villkor</strong></p><p>&nbsp;</p><p>Tidsbegränsad anställning på deltid (intermittent anställning)<strong>&nbsp;</strong>med start omgående.&nbsp;</p><p>\xa0</p><p><strong>Din ansökan</strong></p><p>&nbsp;</p><p>Vi jobbar effektivt och modernt.&nbsp;Istället för ett personligt brev börjar vi med ett antal urvalsfrågor och två arbetspsykologiska tester som du får direkt efter att du skickat in ditt CV. Det ger oss en objektiv bild av din potential och du får snabb feedback. Urval sker löpande och tjänsten kan komma att tillsättas innan sista ansökningsdagen, så vänta inte med din ansökan.</p><p>\xa0</p><p>Inom förskoleverksamhet, skola och skolbarnomsorg måste du enligt Lag (2000:873) uppvisa registerutdrag för arbete inom skolväsendet. Begäran görs via Polisens https://polisen.se/tjanster-tillstand/belastningsregistret/ med digitalt BankID. Du kan också beställa hem blanketten vilket du bör göra snarast då det kan ta tid. Notera att registerutdraget är giltigt i 6 månader.</p><p><strong>Frågor?</strong></p><p>&nbsp;</p><p>Vill du veta mer om tjänsten, vänligen kontakta Rektor Päivi Säteri&nbsp;på paivi.sateri@jenseneducation.se alt. 0737 73 10 53.</p><p>\xa0</p><p><strong>Varmt välkommen med din ansökan!</strong></p><p>&nbsp;</p><p>&nbsp;</p><p>JENSEN education är ett av Sveriges största privata utbildningsföretag med förtroendet att utbilda drygt 17 000 elever inom fem olika områden – förskola, grundskola, gymnasium, vuxenutbildning samt yrkeshögskola. JENSEN grun ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': '1paU_aCR_nGn',
#     'label': 'Behovsanställning',
#     'legacy_ams_taxonomy_id': '4'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'working_hours_type': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'scope_of_work': {'min': None, 'max': None},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.jenseneducation.se/',
#     'organization_number': '5565327201',
#     'name': 'Jensen education Aktiebolag',
#     'workplace': 'JENSEN Education'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobb.jenseneducation.se/job-details.html?rmpage=job&rmjob=4968&utm_medium=talentech_publishing&utm_source=jobtip',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'Nzmh_iTb_z7h',
#     'label': 'Lärare i grundskolan, årskurs 4-6',
#     'legacy_ams_taxonomy_id': '7653'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Döbelnsgatan 2B',
#     'postcode': '75237',
#     'city': 'Uppsala',
#     'coordinates': [17.6363654422059, 59.845397191092]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Döbelnsgatan 2B',
#      'postcode': '75237',
#      'city': 'Uppsala',
#      'coordinates': [17.6363654422059, 59.845397191092]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Päivi Säteri',
#      'description': None,
#      'email': 'paivi.sateri@jenseneducation.se',
#      'telephone': '+46737731053',
#      'contact_type': 'Rektor'}],
#    'publication_date': '2026-09-07T07:57:32',
#    'last_publication_date': '2026-10-04T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1788760652930},
#   {'relevance': 1.0,
#    'id': '31404665',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31404665',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2021004615/logotyper/logo.png',
#    'headline': 'Lärare i säkerhetstjänst',
#    'application_deadline': '2026-09-21T23:59:59',
#    'number_of_vacancies': 2,
# ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#     'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5591070213',
#     'name': 'PersonalExpressen AB',
#     'workplace': 'Uppsala'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://personalexpressen.weselect.com/p/71556-larare-copy',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'VZoJ_4oe_xyR',
#     'label': 'Lärare i grundskolan, årskurs 1-6',
#     'legacy_ams_taxonomy_id': '7750'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': None,
#      'postcode': None,
#      'city': None,
#      'coordinates': [None, None]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': 'VZoJ_4oe_xyR',
#       'label': 'Lärare i grundskolan, årskurs 1–6',
#       'legacy_ams_taxonomy_id': '7750'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-08-13T17:47:25',
#    'last_publication_date': '2026-12-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1786636045736},
#   {'relevance': 1.0,
#    'id': '31350785',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31350785',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5591070213/logotyper/logo.png',
#    'headline': 'Jobba som lågstadielärare på Sveriges mest personliga bemanningsföretag!',
#    'application_deadline': '2026-12-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Lärarkonsult – lågstadielärare med 60 000 kr/månad\nÄr du behörig lågstadielärare och vill arbeta som lärarkonsult på längre uppdrag – med möjlighet till en lön på upp till 60 000 kr per månad? Då vill vi gärna komma i kontakt med dig!\nPersonalExpressen Lärarbemanning söker engagerade och behöriga lågstadielärare som vill arbeta som lärarkonsulter på skolor runt om i Sverige.\nVi samarbetar med både kommunala och fristående skolor och får löpande in nya uppdrag. Som lärarkonsult får du möjlighet att arbeta på samma skola under en hel termin eller ett helt läsår, bygga relationer med elever och kollegor och bli en viktig del av skolans verksamhet.\nUpp till 60 000 kr per månad\nVi vet att erfarna och behöriga lärare är eftertraktade. Därför erbjuder vi upp till 60 000 kr per månad, beroende på uppdrag, behörighet och erfarenhet.\nHos oss får du möjlighet att kombinera en attraktiv lön med längre uppdrag, kontinuitet och nya erfarenheter.\nVi står för boende och resa\nVill du prova att arbeta på en annan ort? Som lärarkonsult hos oss kan du få möjlighet att ta uppdrag på andra platser i Sverige.\nOm uppdraget innebär arbete på annan ort står vi för boende och resa till och från uppdraget.\nDet innebär att du kan ta del av spännande läraruppdrag runt om i Sverige utan att själv behöva stå för kostnaderna för boende och resa.\nSom lärarkonsult gör du skillnad\nSom lågstadielärare spelar du en viktig roll i elevernas första skolår. Du får möjlighet att skapa en trygg, inspirerande och utvecklande lärmiljö där eleverna får bygga en stabil grund för sitt fortsatta lärande.\nUppdragen kan se olika ut beroende på skola och din behörighet. Det kan exempelvis handla om ett klassläraruppdrag eller undervisning i årskurs F–3.\nDu blir en viktig del av skolans ordinarie verksamhet och arbetar nära elever, kollegor och skolledning.\nVi söker dig som:\när utbildad och behörig lärare för förskoleklass och/eller årskurs 1–3\nvill arbeta som lärarkonsult\nhar ett genuint engagemang för elever och lärande\när trygg, tydlig och pedagogisk i din lärarroll\nhar lätt för att skapa goda relationer med elever, vårdnadshavare och kollegor\när ansvarstagande och lösningsorienterad\nsnabbt kan sätta dig in i en ny skolmiljö\nvill arbeta i längre uppdrag och följa elevernas utveckling över tid.\n\n\n\nDet här erbjuder vi\nHos PersonalExpressen Lärarbemanning får du mer än ett läraruppdrag. Vi vill att du ska känna dig uppskattad, trygg och väl omhändertagen genom hela uppdraget.\nVi erbjuder bland annat:\nupp till 60 000 kr i månadslön\ntermins- och läsårsuppdrag\nattraktiva anställningsvillkor\nmöjlighet att påverka vilken typ av uppdrag du är intresserad av\npersonlig kontakt och stöd genom hela uppdraget\nmöjlighet att utvecklas genom nya skolmiljöer och erfarenheter\nmöjlighet att arbeta på olika platser runt om i Sverige.\n\n\n\nVi tror på långsiktiga relationer och vill hitta rätt skola och rätt uppdrag för dig. Vårt mål är att du ska kunna fokusera på det viktigaste – undervisningen och elevernas utveckling – medan vi hjälper till med resten.\nÄr du redo för ditt nästa uppdrag som lärarkonsult?\nAttraktiv lön. Längre uppdrag. Nya möjligheter. Möjlighet att göra verklig skillnad.\nÄr du behörig lågstadielärare och vill ta nästa steg som lärarkonsult?\nSkicka in din ansökan till PersonalExpressen Lärarbemanning redan idag!\nVi ser fram emot att lära känna dig och hitta ditt nästa läraruppdrag.',
#     'text_formatted': '<p><strong>Lärarkonsult – lågstadielärare med 60 000 kr/månad</strong></p><p>Är du behörig lågstadielärare och vill arbeta som lärarkonsult på längre uppdrag – med möjlighet till en lön på upp till 60 000 kr per månad? Då vill vi gärna komma i kontakt med dig!</p><p><strong>PersonalExpressen Lärarbemanning söker engagerade och behöriga lågstadielärare som vill arbeta som lärarkonsulter</strong> på skolor runt om i Sverige.</p><p>Vi samarbetar med både kommunala och fristående skolor och får löpande in nya uppdrag. Som lärarkonsult får du möjlighet att arbeta på samma skola under en hel termin eller ett helt läsår, bygga relationer med elever och kollegor och bli en viktig del av skolans verksamhet.</p><p><strong>Upp till 60 000 kr per månad</strong></p><p><strong>Vi vet att erfarna och behöriga lärare är eftertraktade. Därför erbjuder vi upp till 60 000 kr per månad</strong>, beroende på uppdrag, behörighet och erfarenhet.</p><p>Hos oss får du möjlighet att kombinera <strong>en attraktiv lön med längre uppdrag, kontinuitet och nya erfarenheter</strong>.</p><p><strong>Vi står för boende och resa</strong></p><p>Vill du prova att arbeta på en annan ort? Som lärarkonsult hos oss kan du få möjlighet att ta uppdrag på andra platser i Sverige.</p><p>Om uppdraget innebär arbete på annan ort står vi för boende och resa till och från uppdraget.</p><p>Det innebär att du kan ta del av spännande läraruppdrag runt om i Sverige utan att själv behöva stå för kostnaderna för boende och resa.</p><p>Som lärarkonsult gör du skillnad</p><p>Som lågstadielärare spelar du en viktig roll i elevernas första skolår. Du får möjlighet att skapa en trygg, inspirerande och utvecklande lärmiljö där eleverna får bygga en stabil grund för sitt fortsatta lärande.</p><p>Uppdragen kan se olika ut beroende på skola och din behörighet. Det kan exempelvis handla om ett klassläraruppdrag eller undervisning i årskurs F–3.</p><p>Du blir en viktig del av skolans ordinarie verksamhet och arbetar nära elever, kollegor och skolledning.</p><p><strong>Vi söker dig som:</strong></p><ul><li>är utbildad och behörig lärare för förskoleklass och/eller årskurs 1–3</li><li>vill arbeta som <strong>lärarkonsult</strong></li><li>har ett genuint engagemang för elever och lärande</li><li>är trygg, tydlig och pedagogisk i din lärarroll</li><li>har lätt för att skapa goda relationer med elever, vårdnadshavare och kollegor</li><li>är ansvarstagande och lösningsorienterad</li><li>snabbt kan sätta dig in i en ny skolmiljö</li><li>vill arbeta i längre uppdrag och följa elevernas utveckling över tid.</li></ul><p><br></p><p><strong>Det här erbjuder vi</strong></p><p><strong>Hos PersonalExpressen Lärarbemanning får du mer än ett läraruppdrag. Vi vill att du ska känna dig uppskattad, trygg och väl omhändertagen genom hela uppdraget.</strong></p><p><strong>Vi erbjuder bland annat:</strong></p><ul><li><strong>upp till 60 000 kr i månadslön</strong></li><li>termins- och läsårsuppdrag</li><li>attraktiva anställningsvillkor</li><li>möjlighet att påverka vilken typ av uppdrag du är intresserad av</li><li>personlig kontakt och stöd genom hela uppdraget</li><li>möjlighet att utvecklas genom nya skolmiljöer och erfarenheter</li><li>möjlighet att arbeta på olika platser runt om i Sverige.</li></ul><p><br></p><p>Vi tror på långsiktiga relationer och vill hitta <strong>rätt skola och rätt uppdrag för dig</strong>. Vårt mål är att du ska kunna fokusera på det viktigaste – undervisningen och elevernas utveckling – medan vi hjälper till med resten.</p><p><strong>Är du redo för ditt nästa uppdrag som lärarkonsult?</strong></p><p><strong>Attraktiv lön. Längre uppdrag. Nya möjligheter. Möjlighet att göra verklig skillnad.</strong></p><p>Är du behörig lågstadielärare och vill ta nästa steg som lärarkonsult?</p><p><strong>Skicka in din ansökan till PersonalExpressen Lärarbemanning redan idag!</strong></p><p><strong>Vi ser fram emot att lära känna dig och hitta ditt nästa läraruppdrag.</strong> ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#     'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5591070213',
#     'name': 'PersonalExpressen AB',
#     'workplace': 'Uppsala'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://personalexpressen.weselect.com/p/71554-larare-copy',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'VZoJ_4oe_xyR',
#     'label': 'Lärare i grundskolan, årskurs 1-6',
#     'legacy_ams_taxonomy_id': '7750'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'workplace_addresses': [{'municipality': 'Uppsala',
#      'municipality_code': '0380',
#      'municipality_concept_id': 'otaF_bQY_4ZD',
#      'region': 'Uppsala län',
#      'region_code': '03',
#      'region_concept_id': 'zBon_eET_fFU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': None,
#      'postcode': None,
#      'city': None,
#      'coordinates': [None, None]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': 'VZoJ_4oe_xyR',
#       'label': 'Lärare i grundskolan, årskurs 1–6',
#       'legacy_ams_taxonomy_id': '7750'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-08-13T17:18:25',
#    'last_publication_date': '2026-12-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1786634305672}]}

# %%
json_response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
len(json_response.get("hits"))
# Out:
# 8
